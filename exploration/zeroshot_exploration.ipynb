# %%
# Step 1: Import necessary modules and classes
import os
import json
import numpy as np
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
import sys

# Get the current working directory
current_dir = os.getcwd()
print(current_dir)

# Check if "src" is not part of the path
if "src" not in current_dir:
    # Adjust path to include 'src'
    src_path = os.path.abspath(os.path.join(current_dir, '..', 'src'))
    sys.path.append(src_path)
from file_handling import FileHandler
from text_processing import TextProcessor

# Step 2: Load configuration
config_file_path = r'C:\Users\nikla\OneDrive\Dokumente\winfoMaster\Masterarbeit\bertopic_ecc\config.json'
with open(config_file_path, 'r') as f:
    config = json.load(f)

# Step 3: Extract variables from configuration
index_file_ecc_folder = config["index_file_ecc_folder"]
folderpath_ecc = config["folderpath_ecc"]
sample_size = config["sample_size"]
document_split = config["document_split"]
section_to_analyze = config["section_to_analyze"]
max_documents = config["max_documents"]
model_load_path = config["model_load_path"]
embedding_model =  config["embedding_model_choice"] 

topic_model = BERTopic.load(model_load_path, embedding_model=embedding_model)
# Out:
# c:\Users\nikla\OneDrive\Dokumente\winfoMaster\Masterarbeit\bertopic_ecc\exploration
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# Zeroshot 9 Topics for the following cells

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_barchart()

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                                           Name  \
# 0     -1     67  -1_glutamine_glutaminase_inhibitor_antibiotic
# 1      0  41710                 0_call_welcome_questions_thank
# 2      1  43738              1_revenues_revenue_sales_increase
# 3      2  25675                  2_expenses_costs_expense_cost
# 4      3  63333                 3_earnings_profit_loss_revenue
# 5      4  53635         4_marketing_businesses_market_industry
# 6      5  20586         5_success_strategy_progress_strategies
# 7      6  24805              6_risks_risk_uncertainties_future
#
#                                       Representation  Representative_Docs
# 0  [glutamine, glutaminase, inhibitor, antibiotic...                  NaN
# 1  [call, welcome, questions, thank, remarks, ple...                  NaN
# 2  [revenues, revenue, sales, increase, increased...                  NaN
# 3  [expenses, costs, expense, cost, expenditures,...                  NaN
# 4  [earnings, profit, loss, revenue, income, incr...                  NaN
# 5  [marketing, businesses, market, industry, oppo...                  NaN
# 6  [success, strategy, progress, strategies, stra...                  NaN
# 7  [risks, risk, uncertainties, future, statement...                  NaN

# %%
topic_model.visualize_barchart()

# %%
topic_model.visualize_barchart()

# %%
topic_model.visualize_barchart()

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_topics()
