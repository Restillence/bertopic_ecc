# %%
# Step 1: Import necessary modules and classes
import os
import json
import numpy as np
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
import sys

# Get the current working directory
current_dir = os.getcwd()
print(current_dir)

# Check if "src" is not part of the path
if "src" not in current_dir:
    # Adjust path to include 'src'
    src_path = os.path.abspath(os.path.join(current_dir, '..', 'src'))
    sys.path.append(src_path)
from file_handling import FileHandler
from text_processing import TextProcessor

# Step 2: Load configuration
config_file_path = r'C:\Users\nikla\OneDrive\Dokumente\winfoMaster\Masterarbeit\bertopic_ecc\config.json'
with open(config_file_path, 'r') as f:
    config = json.load(f)

# Step 3: Extract variables from configuration
index_file_ecc_folder = config["index_file_ecc_folder"]
folderpath_ecc = config["folderpath_ecc"]
sample_size = config["sample_size"]
document_split = config["document_split"]
section_to_analyze = config["section_to_analyze"]
max_documents = config["max_documents"]
model_load_path = config["model_load_path"]
embedding_model =  config["embedding_model_choice"] 

topic_model = BERTopic.load(model_load_path, embedding_model=embedding_model)
# Out:
# c:\Users\nikla\OneDrive\Dokumente\winfoMaster\Masterarbeit\bertopic_ecc\exploration

# %% [markdown]
# Zeroshot 9 Topics for the following cells

# %% [markdown]
# regular, nr topics auto, 3000 full random:

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_barchart(top_n_topics=10,n_words=10).show()

# %%
topic_model.get_topic_info()
# Out:
#      Topic   Count                                               Name  \
# 0       -1  131657          -1_industry_business_increase_development
# 1        0   18476                      0_morning_pleased_happy_today
# 2        1   38688                    1_sales_revenues_revenue_growth
# 3        2   22601                         2_costs_cost_revenue_total
# 4        3   58620  3_earnings_income_financial results_profitability
# ..     ...     ...                                                ...
# 106    105    1268  105_fourth quarter_second quarter_end quarter_...
# 107    106     312  106_press release_quarter results_results quar...
# 108    107    1662  107_financial results_quarter results_review_r...
# 109    108    1211  108_guidance_quarter 2017_quarter year_fiscal ...
# 110    109     652  109_quarter results_results quarter_financial ...
#
#                                         Representation  Representative_Docs
# ...

# %%
print(topic_model.get_topic_info(5))
print(topic_model.get_topic_info(6))
print(topic_model.get_topic_info(7))
print(topic_model.get_topic_info(8))
# Out:
#    Topic  Count                                   Name  \
# 0      5  15987  5_risk_future_going forward_prospects
#
#                                       Representation  Representative_Docs
# 0  [risk, future, going forward, prospects, certa...                  NaN
#    Topic  Count                      Name  \
# 0      6    447  6_ahead_sure_let_allowed
#
#                                       Representation  Representative_Docs
# 0  [ahead, sure, let, allowed, wanted, let turn, ...                  NaN
#    Topic  Count                           Name  \
# 0      7    209  7_today_note_morning_reminder
#
#                                       Representation  Representative_Docs
# 0  [today, note, morning, reminder, quality, conf...                  NaN
#    Topic  Count                Name                     Representation  \
# 0      8    239  8_time_currently__  [time, currently, , , , , , , , ]
#
#    Representative_Docs
# 0                  NaN

# %%
topic_model.visualize_barchart()

# %%
topic_model.visualize_barchart()

# %% [markdown]
# regular 3000 full random, nr topics null

# %%
topic_model.visualize_barchart()

# %% [markdown]
# regular bertopic model -> nr topics auto ist viel besser!

# %%
topic_model.visualize_hierarchy()

# %% [markdown]
# bertopic_model_dir_3000full_zeroshot_03minsim_seed

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_barchart()

# %%
topic_model.visualize_topics()

# %% [markdown]
# bertopic_model_dir_3000full_zeroshot_03minsim_seed_huang

# %%
topic_model.visualize_barchart()

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_topics()

# %%
topic_model.get_topic_info()
# Out:
#      Topic   Count                                               Name  \
# 0       -1  124140              -1_customers_customer_company_markets
# 1        0    2405          0_regulatory_compliance_financial_markets
# 2        1    4850                1_risk_statements_prospects_certain
# 3        2    3503      2_competitive_strategic_capabilities_industry
# 4        3    5047            3_customers_consumer_marketing_customer
# ..     ...     ...                                                ...
# 113    112    1039  112_fourth quarter_second quarter_end quarter_...
# 114    113     933  113_results quarter_quarter results_pleased_fo...
# 115    114     580                       114_year_year year_2013_2012
# 116    115     407       115_technologies_performance_capacity_future
# 117    116    2033  116_infrastructure_technologies_network_integr...
#
#                                         Representation  Representative_Docs
# ...

# %%
topic_model.get_topic_freq()
# Out:
#      Topic   Count
# 2       -1  124140
# 0        7   68208
# 17       5   36181
# 16      11   22460
# 27       9   17926
# ..     ...     ...
# 85      20     222
# 112     40     212
# 97      65     206
# 81      22     205
# 115     25     204
#
# [118 rows x 2 columns]

# %%
for i in range(-1,40,1):
    print(topic_model.get_topic_info(i))

# %%
print(topic_model.get_topic_info(7))
print(topic_model.get_topic_info(5))
print(topic_model.get_topic_info(9))
print(topic_model.get_topic_info(11))
# Out:
#    Topic  Count                                          Name  \
# 0      7  68208  7_earnings_income_financial results_revenues
#
#                                       Representation  Representative_Docs
# 0  [earnings, income, financial results, revenues...                  NaN
#    Topic  Count                                Name  \
# 0      5  36181  5_sales_sale_profitability_selling
#
#                                       Representation  Representative_Docs
# 0  [sales, sale, profitability, selling, revenues...                  NaN
#    Topic  Count                                         Name  \
# 0      9  17926  9_investments_investment_investors_investor
#
#                                       Representation  Representative_Docs
# 0  [investments, investment, investors, investor,...                  NaN
#    Topic  Count                              Name  \
# 0     11  22460  11_growth_growing_grow_increases
#
# ...

# %% [markdown]
# Conclusion Huang Zeroshot topic list: some zeroshot topics are too similar

# %% [markdown]
# bertopic_model_dir_3000full_zeroshot_03minsim_seed_huang_own

# %%
topic_model.visualize_barchart()

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_topics()

# %%
for i in range(-1,40,1):
    print(topic_model.get_topic_info(i))
# Out:
#    Topic   Count                               Name  \
# 0     -1  107724  -1_growth_sales_customers_markets
#
#                                       Representation  Representative_Docs
# 0  [growth, sales, customers, markets, market, in...                  NaN
#    Topic  Count                                         Name  \
# 0      0   3950  0_statements_press release_security_private
#
#                                       Representation  Representative_Docs
# 0  [statements, press release, security, private,...                  NaN
#    Topic  Count                                               Name  \
# 0      1   8499  1_risk_statements_financial performance_estimates
#
#                                       Representation  Representative_Docs
# 0  [risk, statements, financial performance, esti...                  NaN
#    Topic  Count                                      Name  \
# 0      2   4056  2_competitive_markets_market_marketplace
#
# ...

# %%
topic_model.get_topic_freq()
# Out:
#     Topic   Count
# 2      -1  107724
# 20      5   43415
# 8       7   29210
# 21     11   28388
# 35     13   21048
# ..    ...     ...
# 10     16     223
# 66     82     222
# 81     68     216
# 61     18     205
# 95     42     201
#
# [113 rows x 2 columns]

# %%
print(topic_model.get_topic_info(5))
print(topic_model.get_topic_info(7))
print(topic_model.get_topic_info(11))
print(topic_model.get_topic_info(13))
# Out:
#    Topic  Count                                Name  \
# 0      5  43415  5_revenues_revenue_sales_increased
#
#                                       Representation  Representative_Docs
# 0  [revenues, revenue, sales, increased, increase...                  NaN
#    Topic  Count                              Name  \
# 0      7  29210  7_earnings_income_revenue_equity
#
#                                       Representation  Representative_Docs
# 0  [earnings, income, revenue, equity, revenues, ...                  NaN
#    Topic  Count                                 Name  \
# 0     11  28388  11_growth_growing_revenue_strategic
#
#                                       Representation  Representative_Docs
# 0  [growth, growing, revenue, strategic, grow, de...                  NaN
#    Topic  Count                            Name  \
# 0     13  21048  13_costs_cost_revenues_revenue
#
#                                       Representation  Representative_Docs
# ...

# %% [markdown]
# bertopic_model_dir_3000full_zeroshot_03minsim_seed_huang_own_auto

# %%
topic_model.visualize_barchart()

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_topics()
