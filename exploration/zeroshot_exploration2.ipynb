# %% [markdown]
# bertopic_model_dir_reg_cuml

# %%
# Step 1: Import necessary modules and classes
import os
import json
import numpy as np
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
import sys

# Get the current working directory
current_dir = os.getcwd()
print(current_dir)

# Check if "src" is not part of the path
if "src" not in current_dir:
    # Adjust path to include 'src'
    src_path = os.path.abspath(os.path.join(current_dir, '..', 'src'))
    sys.path.append(src_path)
from file_handling import FileHandler
from text_processing import TextProcessor

# Step 2: Load configuration
config_file_path = r'C:\Users\nikla\OneDrive\Dokumente\winfoMaster\Masterarbeit\bertopic_ecc\config.json'
with open(config_file_path, 'r') as f:
    config = json.load(f)

# Step 3: Extract variables from configuration
index_file_ecc_folder = config["index_file_ecc_folder"]
folderpath_ecc = config["folderpath_ecc"]
sample_size = config["sample_size"]
document_split = config["document_split"]
section_to_analyze = config["section_to_analyze"]
max_documents = config["max_documents"]
model_load_path = config["model_load_path"]
embedding_model =  config["embedding_model_choice"] 

topic_model = BERTopic.load(model_load_path, embedding_model=embedding_model)
# Out:
# c:\Users\nikla\OneDrive\Dokumente\winfoMaster\Masterarbeit\bertopic_ecc\exploration

# %%
topic_model.visualize_barchart()

# %%
#get topic info in ascending order sorted by count
topic_model.get_topic_info().sort_values(by="Count", ascending=False).head(20)
# Out:
#     Topic   Count                                               Name  \
# 0      -1  423901                   -1_revenues_sales_revenue_profit
# 1       0   21509                 0_medical_health_marketing_markets
# 2       1   12743  1_revenue growth_quarter increased_revenue_rev...
# 3       2   11205         2_financial results_risk_results_regarding
# 4       3   10535          3_customers_marketing_customer_businesses
# 5       4   10118            4_conference_corporation_corporate_mike
# 6       5    9707                5_margin_margins_leverage_decreased
# 7       6    7827  6_earnings_quarter results_quarter 2019_quarte...
# 8       7    6327                   7_production_supply_gas_pipeline
# 9       8    5901                 8_sales_decrease_decline_decreased
# 10      9    5466                     9_questions_open_calls_opening
# 11     10    4283          10_ebitda_earnings_million quarter_income
# 12     11    4262      11_accounting_gaap_earnings_financial results
# 13     12    3766                         12_tax_income_fiscal_rates
# 14     13    3599      13_earnings_net income_income_quarter million
# 15     14    3377         14_progress_going forward_little bit_doing
# 16     15    3268                              15_say_talk_mike_come
# 17     16    3173                        16_morning_steve_good_today
# 18     17    2966  17_financial results_quarter results_financial...
# 19     18    2926               18_shareholders_stock_earnings_share
#
#                                        Representation  Representative_Docs
# 0   [revenues, sales, revenue, profit, production,...                  NaN
# 1   [medical, health, marketing, markets, developm...                  NaN
# 2   [revenue growth, quarter increased, revenue, r...                  NaN
# 3   [financial results, risk, results, regarding, ...                  NaN
# 4   [customers, marketing, customer, businesses, c...                  NaN
# 5   [conference, corporation, corporate, mike, lea...                  NaN
# 6   [margin, margins, leverage, decreased, decreas...                  NaN
# 7   [earnings, quarter results, quarter 2019, quar...                  NaN
# 8   [production, supply, gas, pipeline, capacity, ...                  NaN
# 9   [sales, decrease, decline, decreased, sale, re...                  NaN
# 10  [questions, open, calls, opening, closing, que...                  NaN
# 11  [ebitda, earnings, million quarter, income, re...                  NaN
# 12  [accounting, gaap, earnings, financial results...                  NaN
# 13  [tax, income, fiscal, rates, fiscal year, earn...                  NaN
# 14  [earnings, net income, income, quarter million...                  NaN
# 15  [progress, going forward, little bit, doing, b...                  NaN
# 16  [say, talk, mike, come, turn, note, john, let,...                  NaN
# 17  [morning, steve, good, today, great, day, john...                  NaN
# 18  [financial results, quarter results, financial...                  NaN
# 19  [shareholders, stock, earnings, share, 25 mill...                  NaN

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_topics()

# %% [markdown]
# small model for testing on cpu

# %%
topic_model.visualize_hierarchy()

# %% [markdown]
# bertopic_model_dir_zeroshot_025minsim_huang_own

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_barchart()

# %%
topic_model.get_topic_info().sort_values(by="Count", ascending=False).head(20)
# Out:
#     Topic  Count                                               Name  \
# 0      -1  71083                     -1_morning_pleased_thank_today
# 6       5  60113          5_sales_revenue_quarter year_year quarter
# 12     11  46484                     11_growth_growing_grow_revenue
# 8       7  42086       7_earnings_financial results_cash flow_stock
# 7       6  29633              6_customers_customer_product_products
# 14     13  28557                   13_costs_cost_increased_increase
# 10      9  28325           9_cash flow_financing_capital_investment
# 9       8  21455           8_operation_employees_operator_operating
# 47     46  16890                  46_research_results_phase_medical
# 2       1  15366         1_statements_financial results_future_risk
# 4       3  14990                  3_demand_market_customers_markets
# 1       0   9808             0_statements_private_forward_regarding
# 5       4   9276             4_economic_businesses_markets_business
# 3       2   7321               2_market_markets_marketing_strategic
# 75     74   7099                        74_ll turn_turn_turning_tom
# 70     69   7061        69_technologies_technology_digital_advanced
# 13     12   6835                12_rates_percent_fiscal_fiscal year
# 49     48   5626                      48_financing_debt_credit_bank
# 81     80   4311  80_press release_release_quarter results_released
# 29     28   4187  28_conference_results quarter_quarter results_...
#
#                                            CustomName  \
# 0                                            Outliers
# 6   SALES: sales, revenue, quarter year, year quar...
# 12  GROWTH: growth, growing, grow, revenue, busine...
# 8   EARNINGS: earnings, financial results, cash fl...
# 7   CONSUMER: customers, customer, product, produc...
# 14  COSTS: costs, cost, increased, increase, reven...
# 10  INVESTMENTS: cash flow, financing, capital, in...
# 9   OPERATIONS: operation, employees, operator, op...
# 47  Topic 46: research, results, phase, medical, h...
# 2   RISK: statements, financial results, future, r...
# 4   CONSUMER: demand, market, customers, markets, ...
# 1   Topic 0: statements, private, forward, regardi...
# 5   GEOGRAPHY: economic, businesses, markets, busi...
# 3   GEOGRAPHY: market, markets, marketing, strateg...
# 75  Topic 74: ll turn, turn, turning, tom, dave, p...
# 70  CONSUMER: technologies, technology, digital, a...
# 13  EARNINGS: rates, percent, fiscal, fiscal year,...
# 49  GROWTH: financing, debt, credit, bank, balance...
# 81  Topic 80: press release, release, quarter resu...
# 29  Topic 28: conference, results quarter, quarter...
#
#                                        Representation  Representative_Docs
# 0   [morning, pleased, thank, today, thanks, compl...                  NaN
# 6   [sales, revenue, quarter year, year quarter, s...                  NaN
# 12  [growth, growing, grow, revenue, business, bus...                  NaN
# 8   [earnings, financial results, cash flow, stock...                  NaN
# 7   [customers, customer, product, products, marke...                  NaN
# 14  [costs, cost, increased, increase, revenue, in...                  NaN
# 10  [cash flow, financing, capital, investment, fi...                  NaN
# 9   [operation, employees, operator, operating, co...                  NaN
# 47  [research, results, phase, medical, health, da...                  NaN
# 2   [statements, financial results, future, risk, ...                  NaN
# 4   [demand, market, customers, markets, marketing...                  NaN
# 1   [statements, private, forward, regarding, rema...                  NaN
# 5   [economic, businesses, markets, business, indu...                  NaN
# 3   [market, markets, marketing, strategic, strate...                  NaN
# 75  [ll turn, turn, turning, tom, dave, pass, come...                  NaN
# 70  [technologies, technology, digital, advanced, ...                  NaN
# 13  [rates, percent, fiscal, fiscal year, rate, ea...                  NaN
# 49  [financing, debt, credit, bank, balance, rates...                  NaN
# 81  [press release, release, quarter results, rele...                  NaN
# 29  [conference, results quarter, quarter results,...                  NaN

# %% [markdown]
# bertopic_model_dir_3000full_zeroshot_03minsim_seed_huang_own

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.get_topic_info().sort_values(by="Count", ascending=False).head(20)
# Out:
#     Topic   Count                                               Name  \
# 0      -1  107724                  -1_growth_sales_customers_markets
# 6       5   43415                 5_revenues_revenue_sales_increased
# 8       7   29210                   7_earnings_income_revenue_equity
# 12     11   28388                11_growth_growing_revenue_strategic
# 14     13   21048                     13_costs_cost_revenues_revenue
# 10      9   18627       9_cash flow_investments_investment_financial
# 81     80   15205                       80_medical_phase_test_health
# 7       6   14636          6_businesses_customers_marketing_services
# 9       8   10781             8_operator_operate_operation_operating
# 2       1    8499  1_risk_statements_financial performance_estimates
# 4       3    7934                 3_demand_customers_consumer_market
# 84     83    7369       83_customers_network_customer_infrastructure
# 5       4    6425     4_outlook_financial_business_financial results
# 37     36    6007        36_margin_margins_year quarter_quarter year
# 15     14    5271             14_marketing_customers_brands_consumer
# 25     24    4838  24_earnings_quarter results_results quarter_qu...
# 13     12    4572                   12_tax_income_fiscal_fiscal year
# 72     71    4441                    71_open_questions_opening_asked
# 3       2    4056           2_competitive_markets_market_marketplace
# 67     66    4048             66_ceo_corporate_corporation_companies
#
#                                        Representation  Representative_Docs
# 0   [growth, sales, customers, markets, market, in...                  NaN
# 6   [revenues, revenue, sales, increased, increase...                  NaN
# 8   [earnings, income, revenue, equity, revenues, ...                  NaN
# 12  [growth, growing, revenue, strategic, grow, de...                  NaN
# 14  [costs, cost, revenues, revenue, spending, inc...                  NaN
# 10  [cash flow, investments, investment, financial...                  NaN
# 81  [medical, phase, test, health, data, research,...                  NaN
# 7   [businesses, customers, marketing, services, b...                  NaN
# 9   [operator, operate, operation, operating, ceo,...                  NaN
# 2   [risk, statements, financial performance, esti...                  NaN
# 4   [demand, customers, consumer, market, customer...                  NaN
# 84  [customers, network, customer, infrastructure,...                  NaN
# 5   [outlook, financial, business, financial resul...                  NaN
# 37  [margin, margins, year quarter, quarter year, ...                  NaN
# 15  [marketing, customers, brands, consumer, marke...                  NaN
# 25  [earnings, quarter results, results quarter, q...                  NaN
# 13  [tax, income, fiscal, fiscal year, earnings, r...                  NaN
# 72  [open, questions, opening, asked, look forward...                  NaN
# 3   [competitive, markets, market, marketplace, st...                  NaN
# 67  [ceo, corporate, corporation, companies, compa...                  NaN

# %%
topic_model.get_topic_info().head(20)
# Out:
#     Topic   Count                                               Name  \
# 0      -1  107724                  -1_growth_sales_customers_markets
# 1       0    3950        0_statements_press release_security_private
# 2       1    8499  1_risk_statements_financial performance_estimates
# 3       2    4056           2_competitive_markets_market_marketplace
# 4       3    7934                 3_demand_customers_consumer_market
# 5       4    6425     4_outlook_financial_business_financial results
# 6       5   43415                 5_revenues_revenue_sales_increased
# 7       6   14636          6_businesses_customers_marketing_services
# 8       7   29210                   7_earnings_income_revenue_equity
# 9       8   10781             8_operator_operate_operation_operating
# 10      9   18627       9_cash flow_investments_investment_financial
# 11     10    1268           10_region_north america_regional_america
# 12     11   28388                11_growth_growing_revenue_strategic
# 13     12    4572                   12_tax_income_fiscal_fiscal year
# 14     13   21048                     13_costs_cost_revenues_revenue
# 15     14    5271             14_marketing_customers_brands_consumer
# 16     15     522                        15_ahead_let_allowed_wanted
# 17     16     223                16_recorded_today_yesterday_morning
# 18     17     559                          17_ahead_thank_questions_
# 19     18     205                        18_begin_started_ready_okay
#
#                                        Representation  Representative_Docs
# 0   [growth, sales, customers, markets, market, in...                  NaN
# 1   [statements, press release, security, private,...                  NaN
# 2   [risk, statements, financial performance, esti...                  NaN
# 3   [competitive, markets, market, marketplace, st...                  NaN
# 4   [demand, customers, consumer, market, customer...                  NaN
# 5   [outlook, financial, business, financial resul...                  NaN
# 6   [revenues, revenue, sales, increased, increase...                  NaN
# 7   [businesses, customers, marketing, services, b...                  NaN
# 8   [earnings, income, revenue, equity, revenues, ...                  NaN
# 9   [operator, operate, operation, operating, ceo,...                  NaN
# 10  [cash flow, investments, investment, financial...                  NaN
# 11  [region, north america, regional, america, eur...                  NaN
# 12  [growth, growing, revenue, strategic, grow, de...                  NaN
# 13  [tax, income, fiscal, fiscal year, earnings, r...                  NaN
# 14  [costs, cost, revenues, revenue, spending, inc...                  NaN
# 15  [marketing, customers, brands, consumer, marke...                  NaN
# 16  [ahead, let, allowed, wanted, start, thank, de...                  NaN
# 17  [recorded, today, yesterday, morning, quarter ...                  NaN
# 18            [ahead, thank, questions, , , , , , , ]                  NaN
# 19  [begin, started, ready, okay, thank, let, good...                  NaN

# %% [markdown]
# reg 1000

# %%
topic_model.get_topic_info().sort_values(by="Count", ascending=False).head(20)
# Out:
#     Topic   Count                                               Name  \
# 0      -1  173371                  -1_sales_revenues_earnings_growth
# 1       0   12631                   0_health_provide_support_ongoing
# 2       1    8231                 1_margin_margins_leverage_revenues
# 3       2    6625  2_financial results_statements_operating resul...
# 4       3    5314          3_customers_customer_marketing_businesses
# 5       4    4784                  4_decrease_sales_decline_revenues
# 6       5    4222  5_quarter results_earnings_conference_quarter ...
# 7       6    3557       6_customers_consumer_infrastructure_customer
# 8       7    3389                          7_john_talked_number_come
# 9       8    2807                  8_ebitda_earnings_income_expenses
# 10      9    2522                     9_sales_sale_revenues_increase
# 11     10    2475                10_slide_presentation_provided_flow
# 12     11    2161                     11_credit_growth_bank_increase
# 13     12    2138  12_financial results_quarter results_earnings_...
# 14     13    2043  13_press release_release_announced_financial r...
# 15     14    2024            14_production_development_plans_planned
# 16     15    1931       15_revenues_revenue_increase_million quarter
# 17     16    1803              16_progress_doing_successful_strategy
# 18     17    1797                       17_brand_products_make_sales
# 19     18    1720        18_acquisitions_acquisition_merger_acquired
#
#                                        Representation  Representative_Docs
# 0   [sales, revenues, earnings, growth, profit, bu...                  NaN
# 1   [health, provide, support, ongoing, including,...                  NaN
# 2   [margin, margins, leverage, revenues, decrease...                  NaN
# 3   [financial results, statements, operating resu...                  NaN
# 4   [customers, customer, marketing, businesses, c...                  NaN
# 5   [decrease, sales, decline, revenues, markets, ...                  NaN
# 6   [quarter results, earnings, conference, quarte...                  NaN
# 7   [customers, consumer, infrastructure, customer...                  NaN
# 8   [john, talked, number, come, turn, say, talk, ...                  NaN
# 9   [ebitda, earnings, income, expenses, revenues,...                  NaN
# 10  [sales, sale, revenues, increase, increased, r...                  NaN
# 11  [slide, presentation, provided, flow, changes,...                  NaN
# 12  [credit, growth, bank, increase, markets, cons...                  NaN
# 13  [financial results, quarter results, earnings,...                  NaN
# 14  [press release, release, announced, financial ...                  NaN
# 15  [production, development, plans, planned, pote...                  NaN
# 16  [revenues, revenue, increase, million quarter,...                  NaN
# 17  [progress, doing, successful, strategy, work, ...                  NaN
# 18  [brand, products, make, sales, retail, marketi...                  NaN
# 19  [acquisitions, acquisition, merger, acquired, ...                  NaN

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_barchart()

# %% [markdown]
# zeroshot 1000

# %%
topic_model.visualize_barchart()

# %%
topic_model.get_topic_info().sort_values(by="Count", ascending=False).head(20)
# Out:
#      Topic   Count                                               Name  \
# 0       -1  174196                 -1_increase_sales_growth_increased
# 16      15   13148                  15_medical_health_benefit_ongoing
# 81      80    8026                80_margin_margins_revenues_leverage
# 34      33    4545          33_corporate_management_companies_company
# 107    106    4468                106_decrease_decline_revenues_sales
# 8        7    4265  7_earnings_quarter results_results quarter_mor...
# 91      90    3174                        90_turn_turning_talked_note
# 15      14    2773                 14_ebitda_earnings_income_revenues
# 143    142    2635          142_customers_customer_marketing_consumer
# 101    100    2566                    100_sales_sale_revenues_revenue
# 55      54    2431              54_slide_presentation_fourth_provided
# 65      64    2358        64_acquisition_acquisitions_acquired_merger
# 128    127    2358               127_credit_bank_prior quarter_equity
# 10       9    2294                     9_morning_happy_good_excellent
# 113    112    2236    112_financial results_review_financial_earnings
# 98      97    2024  97_press release_financial results_earnings_an...
# 134    133    1959     133_customers_customer_services_infrastructure
# 103    102    1935            102_revenues_revenue_increase_increased
# 73      72    1837                    72_sales_growth_products_retail
# 80      79    1790            79_production_development_planned_plans
#
#                                             CustomName  \
# 0                                             Outliers
# 16   PRODUCTS: medical, health, benefit, ongoing, e...
# 81   GROWTH: margin, margins, revenues, leverage, r...
# 34   CONSUMER: corporate, management, companies, co...
# 107  SALES: decrease, decline, revenues, sales, rev...
# 8    EARNINGS: earnings, quarter results, results q...
# 91   Topic 90: turn, turning, talked, note, say, nu...
# 15   EARNINGS: ebitda, earnings, income, revenues, ...
# 143  CONSUMER: customers, customer, marketing, cons...
# 101  SALES: sales, sale, revenues, revenue, total, ...
# 55   SALES: slide, presentation, fourth, provided, ...
# 65   GROWTH: acquisition, acquisitions, acquired, m...
# 128  GEOGRAPHY: credit, bank, prior quarter, equity...
# 10   Topic 9: morning, happy, good, excellent, grea...
# 113  EARNINGS: financial results, review, financial...
# 98   EARNINGS: press release, financial results, ea...
# 134  CONSUMER: customers, customer, services, infra...
# 103  SALES: revenues, revenue, increase, increased,...
# 73   SALES: sales, growth, products, retail, market...
# 80   PRODUCTS: production, development, planned, pl...
#
#                                         Representation  Representative_Docs
# 0    [increase, sales, growth, increased, revenues,...                  NaN
# 16   [medical, health, benefit, ongoing, efforts, p...                  NaN
# 81   [margin, margins, revenues, leverage, revenue,...                  NaN
# 34   [corporate, management, companies, company, ge...                  NaN
# 107  [decrease, decline, revenues, sales, revenue, ...                  NaN
# 8    [earnings, quarter results, results quarter, m...                  NaN
# 91   [turn, turning, talked, note, say, number, com...                  NaN
# 15   [ebitda, earnings, income, revenues, fiscal, r...                  NaN
# 143  [customers, customer, marketing, consumer, bus...                  NaN
# 101  [sales, sale, revenues, revenue, total, market...                  NaN
# 55   [slide, presentation, fourth, provided, 10, nu...                  NaN
# 65   [acquisition, acquisitions, acquired, merger, ...                  NaN
# 128  [credit, bank, prior quarter, equity, quality,...                  NaN
# 10   [morning, happy, good, excellent, great, today...                  NaN
# 113  [financial results, review, financial, earning...                  NaN
# 98   [press release, financial results, earnings, a...                  NaN
# 134  [customers, customer, services, infrastructure...                  NaN
# 103  [revenues, revenue, increase, increased, quart...                  NaN
# 73   [sales, growth, products, retail, marketing, c...                  NaN
# 80   [production, development, planned, plans, 500,...                  NaN

# %%
topic_model.get_topic_info().head(20)
# Out:
#     Topic   Count                                               Name  \
# 0      -1  174196                 -1_increase_sales_growth_increased
# 1       0       1                          0_expenses_costs_turning_
# 2       1     378                      1_ahead_morning_good_question
# 3       2     321                                   2_morning_good__
# 4       3     225                      3_recorded_today_morning_good
# 5       4     548                            4_come_ahead_want_press
# 6       5     267                    5_attention_time_good_currently
# 7       6     383              6_conference_event_presentation_great
# 8       7    4265  7_earnings_quarter results_results quarter_mor...
# 9       8     280                       8_begin_began_guidance_ahead
# 10      9    2294                     9_morning_happy_good_excellent
# 11     10     713                                10_days_day_june_48
# 12     11     417                     11_morning_calls_today_pleased
# 13     12     328                       12_pleased_happy_today_going
# 14     13     918             13_future_date_statement_press release
# 15     14    2773                 14_ebitda_earnings_income_revenues
# 16     15   13148                  15_medical_health_benefit_ongoing
# 17     16     473                     16_form_issued_10_september 30
# 18     17     300                 17_stated_discussed_future_private
# 19     18     269               18_statement_remarks_risk_discussion
#
#                                            CustomName  \
# 0                                            Outliers
# 1       COSTS: expenses, costs, turning, , , , , , ,
# 2   Topic 1: ahead, morning, good, question, , , ,...
# 3              Topic 2: morning, good, , , , , , , ,
# 4   Topic 3: recorded, today, morning, good, , , ,...
# 5   Topic 4: come, ahead, want, press, turn, remai...
# 6   Topic 5: attention, time, good, currently, ass...
# 7   Topic 6: conference, event, presentation, grea...
# 8   EARNINGS: earnings, quarter results, results q...
# 9   Topic 8: begin, began, guidance, ahead, , , , ...
# 10  Topic 9: morning, happy, good, excellent, grea...
# 11  Topic 10: days, day, june, 48, 65, month, 70, ...
# 12  Topic 11: morning, calls, today, pleased, happ...
# 13  Topic 12: pleased, happy, today, going, coming...
# 14  Topic 13: future, date, statement, press relea...
# 15  EARNINGS: ebitda, earnings, income, revenues, ...
# 16  PRODUCTS: medical, health, benefit, ongoing, e...
# 17  TAX: form, issued, 10, september 30, tax, marc...
# 18  Topic 17: stated, discussed, future, private, ...
# 19  RISK: statement, remarks, risk, discussion, de...
#
#                                        Representation  Representative_Docs
# 0   [increase, sales, growth, increased, revenues,...                  NaN
# 1            [expenses, costs, turning, , , , , , , ]                  NaN
# 2        [ahead, morning, good, question, , , , , , ]                  NaN
# 3                     [morning, good, , , , , , , , ]                  NaN
# 4        [recorded, today, morning, good, , , , , , ]                  NaN
# 5   [come, ahead, want, press, turn, remain, great...                  NaN
# 6   [attention, time, good, currently, associated,...                  NaN
# 7   [conference, event, presentation, great, mark,...                  NaN
# 8   [earnings, quarter results, results quarter, m...                  NaN
# 9         [begin, began, guidance, ahead, , , , , , ]                  NaN
# 10  [morning, happy, good, excellent, great, today...                  NaN
# 11  [days, day, june, 48, 65, month, 70, 60, decre...                  NaN
# 12  [morning, calls, today, pleased, happy, rest, ...                  NaN
# 13   [pleased, happy, today, going, coming, , , , , ]                  NaN
# 14  [future, date, statement, press release, chang...                  NaN
# 15  [ebitda, earnings, income, revenues, fiscal, r...                  NaN
# 16  [medical, health, benefit, ongoing, efforts, p...                  NaN
# 17  [form, issued, 10, september 30, tax, march 31...                  NaN
# 18  [stated, discussed, future, private, financial...                  NaN
# 19  [statement, remarks, risk, discussion, details...                  NaN

# %% [markdown]
# reg 2500 null

# %%
topic_model.get_topic_info().sort_values(by="Count", ascending=False).head(20)
# Out:
#     Topic   Count                                               Name  \
# 0      -1  191859               -1_sales_marketing_business_revenues
# 1       0   15103         0_companies_business_marketing_development
# 2       1    9283               1_margin_margins_leverage_percentage
# 3       2    8873          2_customers_marketing_customer_businesses
# 4       3    6643                3_decrease_decline_revenues_revenue
# 5       4    4925  4_earnings_earnings release_financial results_...
# 6       5    4597                     5_questions_open_opening_calls
# 7       6    3707        6_corporate_corporation_investor_management
# 8       7    3308                     7_tax_fiscal year_fiscal_rates
# 9       8    3278                    8_little bit_briefly_little_bit
# 10      9    3206           9_earnings_million quarter_income_margin
# 11     10    3155              10_portfolio_credit_growth_investment
# 12     11    2817        11_production_development_operational_early
# 13     12    2728  12_financial results_quarter results_results q...
# 14     13    2727      13_balance sheet_cash flow_financial_leverage
# 15     14    2458                 14_slide_presentation_fourth_trend
# 16     15    2372  15_quarter results_results quarter_financial r...
# 18     17    2343  17_revenues_revenue_million quarter_quarter fi...
# 17     16    2343                             16_calls_talk_say_turn
# 19     18    2222                   18_sales_increase_sale_increased
#
#                                        Representation  Representative_Docs
# 0   [sales, marketing, business, revenues, product...                  NaN
# 1   [companies, business, marketing, development, ...                  NaN
# 2   [margin, margins, leverage, percentage, quarte...                  NaN
# 3   [customers, marketing, customer, businesses, b...                  NaN
# 4   [decrease, decline, revenues, revenue, sales, ...                  NaN
# 5   [earnings, earnings release, financial results...                  NaN
# 6   [questions, open, opening, calls, closing, que...                  NaN
# 7   [corporate, corporation, investor, management,...                  NaN
# 8   [tax, fiscal year, fiscal, rates, rate, prior ...                  NaN
# 9   [little bit, briefly, little, bit, just, discu...                  NaN
# 10  [earnings, million quarter, income, margin, re...                  NaN
# 11  [portfolio, credit, growth, investment, increa...                  NaN
# 12  [production, development, operational, early, ...                  NaN
# 13  [financial results, quarter results, results q...                  NaN
# 14  [balance sheet, cash flow, financial, leverage...                  NaN
# 15  [slide, presentation, fourth, trend, seven, wa...                  NaN
# 16  [quarter results, results quarter, financial r...                  NaN
# 18  [revenues, revenue, million quarter, quarter f...                  NaN
# 17  [calls, talk, say, turn, number, come, mike, n...                  NaN
# 19  [sales, increase, sale, increased, revenues, r...                  NaN

# %%
topic_model.visualize_hierarchy()

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_barchart()

# %% [markdown]
# bertopic_model_dir_regular_2500_auto

# %%
topic_model.visualize_barchart()

# %%
topic_model.get_topic_info().sort_values(by="Count", ascending=False).head(20)
# Out:
#    Topic   Count                                               Name  \
# 0     -1  191859              -1_revenue_revenues_business_earnings
# 1      0  164853                  0_earnings_revenues_sales_revenue
# 2      1    1099  1_obligation update_update forward_update stat...
# 3      2     844                 2_ahead sir_sir begin_sir_ahead mr
# 4      3     706         3_theft auto_playstation_games_grand theft
# 5      4     373           4_ahead thanks_ahead_ahead ahead_allowed
# 6      5     327         5_aircraft_airplanes_new aircraft_aviation
#
#                                       Representation  Representative_Docs
# 0  [revenue, revenues, business, earnings, growth...                  NaN
# 1  [earnings, revenues, sales, revenue, cash flow...                  NaN
# 2  [obligation update, update forward, update sta...                  NaN
# 3  [ahead sir, sir begin, sir, ahead mr, sir than...                  NaN
# 4  [theft auto, playstation, games, grand theft, ...                  NaN
# 5  [ahead thanks, ahead, ahead ahead, allowed, th...                  NaN
# 6  [aircraft, airplanes, new aircraft, aviation, ...                  NaN

# %%
topic_model.visualize_hierarchy()

# %% [markdown]
# 2500 reg nr topics 20

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_barchart()

# %%
topic_model.get_topic_info().sort_values(by="Count", ascending=False).head(20)
# Out:
#     Topic   Count                                               Name  \
# 0      -1  191859                -1_revenue_revenues_growth_business
# 1       0   64502           0_revenues_expenses_expenditures_revenue
# 2       1   23415             1_marketing_business_businesses_market
# 3       2   17732                   2_chairman_ceo_president ceo_cfo
# 4       3   15797              3_clinical_treatment_patients_patient
# 5       4   12599  4_financial results_financial performance_fina...
# 6       5    8608  5_earnings conference_quarter earnings_earning...
# 7       6    5376             6_production_oil gas_natural gas_wells
# 8       7    3995  7_performance quarter_quarter performance_resu...
# 9       8    3928          8_uncertainties_risks_risk_future results
# 10      9    2416        9_updates_obligation_forward looking_update
# 11     10    2208  10_non gaap_earnings press_earnings release_ga...
# 12     11    1996      11_webcast_available website_recorded_calling
# 13     12    1801   12_broadband_telecom_service providers_providers
# 14     13    1217                      13_ahead_okay_ll turn_allowed
# 15     14     742                  14_listen_broadcast_audience_mode
# 16     15     706                    15_theater_disney_film_cinemark
# 17     16     610                16_litigation_court_appeal_judgment
# 18     17     327                      17_airlines_jet_airtran_fleet
# 19     18     227             18_numbers_number_amounts_large number
#
#                                        Representation  Representative_Docs
# 0   [revenue, revenues, growth, business, profit, ...                  NaN
# 1   [revenues, expenses, expenditures, revenue, ex...                  NaN
# 2   [marketing, business, businesses, market, cust...                  NaN
# 3   [chairman, ceo, president ceo, cfo, executive,...                  NaN
# 4   [clinical, treatment, patients, patient, thera...                  NaN
# 5   [financial results, financial performance, fin...                  NaN
# 6   [earnings conference, quarter earnings, earnin...                  NaN
# 7   [production, oil gas, natural gas, wells, dril...                  NaN
# 8   [performance quarter, quarter performance, res...                  NaN
# 9   [uncertainties, risks, risk, future results, r...                  NaN
# 10  [updates, obligation, forward looking, update,...                  NaN
# 11  [non gaap, earnings press, earnings release, g...                  NaN
# 12  [webcast, available website, recorded, calling...                  NaN
# 13  [broadband, telecom, service providers, provid...                  NaN
# 14  [ahead, okay, ll turn, allowed, gentlemen, beg...                  NaN
# 15  [listen, broadcast, audience, mode, participan...                  NaN
# 16  [theater, disney, film, cinemark, sales, reven...                  NaN
# 17  [litigation, court, appeal, judgment, cases, s...                  NaN
# 18  [airlines, jet, airtran, fleet, deliveries, cr...                  NaN
# 19  [numbers, number, amounts, large number, calcu...                  NaN

# %%
topic_model.visualize_hierarchy()

# %% [markdown]
# 2500 reg nr topics 40

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_barchart()

# %%
topic_model.get_topic_info().sort_values(by="Count", ascending=False).head(40)
# Out:
#     Topic   Count                                               Name  \
# 0      -1  191859                 -1_revenue_revenues_sales_business
# 1       0   45637             0_gross margin_margin_margins_earnings
# 2       1   15580                 1_clinical_phase_medical_treatment
# 3       2   15300        2_earnings share_earnings_net income_shares
# 4       3   12458             3_customers_customer_marketing_clients
# 5       4    9857          4_ceo_board directors_executive_directors
# 6       5    8481  5_financial results_financial performance_quar...
# 7       6    7875                       6_questions_open_ask_request
# 8       7    6469  7_quarter earnings_earnings_earnings release_f...
# 9       8    3995  8_strong quarter_results quarter_quarter resul...
# 10      9    3449     9_cash flows_cash flow_balance sheet_financial
# 11     10    3208                   10_production_producing_12_years
# 12     11    2987                       11_stores_store_retail_sales
# 13     12    2773  12_litigation_statements_forward looking_secur...
# 14     13    2766             13_customers_customer_clients_bookings
# 15     14    2458              14_slide_slides_presentation_let turn
# 16     15    2416      15_obligations_update_updates_forward looking
# 17     16    2208  16_non gaap_gaap_financial results_earnings re...
# 18     17    2168                      17_oil_production_fuel_supply
# 19     18    2139                   18_morning_welcome_thank_evening
# 20     19    1996  19_webcast_press release_recorded_earnings rel...
# 21     20    1660                      20_risks_risk_factors_filings
# 22     21    1596       21_video_communications_technologies_channel
# 23     22    1548         22_acquisitions_acquisition_acquire_merger
# 24     23    1155                  23_risks_risk_caution_uncertainty
# 25     24    1064                24_currency_exchange_dollars_dollar
# 26     25    1025              25_inventory_inventories_stock_supply
# 27     26     844                         26_ahead_mr_allowed_thanks
# 28     27     742           27_broadcast_audience_participants_audio
# 29     28     733                     28_days_90 days_sales_decrease
# 30     29     706                          29_game_play_played_award
# 31     30     610         30_settlement_litigation_claims_commission
# 32     31     497  31_flat_year quarter_quarter year_quarter revenue
# 33     32     373                        32_begin_beginning_start_mr
# 34     33     327                 33_fleet_deliveries_delivery_lease
# 35     34     246                   34_cash flow_debt_cash_liquidity
# 36     35     227                    35_numbers_number_digit_amounts
# 37     36     217                   36_safety_safe_employees_protect
# 38     37     207  37_manufacturing_production_transportation_ind...
# 39     38     205               38_growth rate_growth_production_bit
#
#                                        Representation  Representative_Docs
# 0   [revenue, revenues, sales, business, growth, e...                  NaN
# 1   [gross margin, margin, margins, earnings, adju...                  NaN
# 2   [clinical, phase, medical, treatment, hospital...                  NaN
# 3   [earnings share, earnings, net income, shares,...                  NaN
# 4   [customers, customer, marketing, clients, cons...                  NaN
# 5   [ceo, board directors, executive, directors, m...                  NaN
# 6   [financial results, financial performance, qua...                  NaN
# 7   [questions, open, ask, request, closing, prepa...                  NaN
# 8   [quarter earnings, earnings, earnings release,...                  NaN
# 9   [strong quarter, results quarter, quarter resu...                  NaN
# 10  [cash flows, cash flow, balance sheet, financi...                  NaN
# 11  [production, producing, 12, years, development...                  NaN
# 12  [stores, store, retail, sales, seven, restaura...                  NaN
# 13  [litigation, statements, forward looking, secu...                  NaN
# 14  [customers, customer, clients, bookings, growt...                  NaN
# 15  [slide, slides, presentation, let turn, number...                  NaN
# 16  [obligations, update, updates, forward looking...                  NaN
# 17  [non gaap, gaap, financial results, earnings r...                  NaN
# 18  [oil, production, fuel, supply, gas, produced,...                  NaN
# 19  [morning, welcome, thank, evening, happy, afte...                  NaN
# 20  [webcast, press release, recorded, earnings re...                  NaN
# 21  [risks, risk, factors, filings, statements, fi...                  NaN
# 22  [video, communications, technologies, channel,...                  NaN
# 23  [acquisitions, acquisition, acquire, merger, a...                  NaN
# 24  [risks, risk, caution, uncertainty, assumption...                  NaN
# 25  [currency, exchange, dollars, dollar, earnings...                  NaN
# 26  [inventory, inventories, stock, supply, shipme...                  NaN
# 27           [ahead, mr, allowed, thanks, , , , , , ]                  NaN
# 28  [broadcast, audience, participants, audio, rec...                  NaN
# 29  [days, 90 days, sales, decrease, day, prior qu...                  NaN
# 30  [game, play, played, award, release, platforms...                  NaN
# 31  [settlement, litigation, claims, commission, p...                  NaN
# 32  [flat, year quarter, quarter year, quarter rev...                  NaN
# 33  [begin, beginning, start, mr, ll turn, okay, a...                  NaN
# 34  [fleet, deliveries, delivery, lease, delivered...                  NaN
# 35  [cash flow, debt, cash, liquidity, balance she...                  NaN
# 36  [numbers, number, digit, amounts, figures, lot...                  NaN
# 37  [safety, safe, employees, protect, company, in...                  NaN
# 38  [manufacturing, production, transportation, in...                  NaN
# 39  [growth rate, growth, production, bit, increas...                  NaN

# %%
topic_model.visualize_hierarchy()

# %% [markdown]
# 2500 zeroshot 0.75

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_barchart()

# %%
topic_model.get_topic_info().sort_values(by="Count", ascending=False).head(20)
# Out:
#      Topic   Count                                               Name  \
# 0       -1  191656             -1_growth_marketing_revenues_customers
# 70      69   14252             69_medical_marketing_markets_customers
# 26      25    9384                 25_margin_margins_revenues_revenue
# 140    139    8242        139_customers_marketing_customer_businesses
# 108    107    6072              107_decrease_revenues_decline_revenue
# 13      12    4663  12_earnings_earnings release_quarter results_f...
# 24      23    4637                    23_questions_open_calls_opening
# 134    133    3793             133_products_industry_product_consumer
# 16      15    3268                15_margin_earnings_margins_adjusted
# 122    121    3237               121_little bit_discuss_think_details
# 127    126    2998            126_credit_portfolio_bank_prior quarter
# 110    109    2779                             109_say_turn_come_mike
# 15      14    2711                         14_morning_happy_rest_good
# 118    117    2631  117_financial results_quarter results_results ...
# 74      73    2615  73_production_development_operational_infrastr...
# 63      62    2595                 62_slide_presentation_trend_fourth
# 116    115    2558  115_financial results_quarter results_financia...
# 123    122    2408                  122_sales_increase_sale_increased
# 131    130    2284  130_revenues_revenue_million quarter_quarter f...
# 78      77    2080         77_acquisition_acquisitions_acquired_sales
#
#                                             CustomName  \
# 0                                             Outliers
# 70   MARKETING: medical, marketing, markets, custom...
# 26   GROWTH: margin, margins, revenues, revenue, pr...
# 140  CONSUMER: customers, marketing, customer, busi...
# 108  SALES: decrease, revenues, decline, revenue, d...
# 13   EARNINGS: earnings, earnings release, quarter ...
# 24   Topic 23: questions, open, calls, opening, clo...
# 134  PRODUCTS: products, industry, product, consume...
# 16   GROWTH: margin, earnings, margins, adjusted, r...
# 122  Topic 121: little bit, discuss, think, details...
# 127  INVESTMENTS: credit, portfolio, bank, prior qu...
# 110  Topic 109: say, turn, come, mike, talk, let, t...
# 15   Topic 14: morning, happy, rest, good, steve, e...
# 118  EARNINGS: financial results, quarter results, ...
# 74   PRODUCTS: production, development, operational...
# 63   Topic 62: slide, presentation, trend, fourth, ...
# 116  EARNINGS: financial results, quarter results, ...
# 123  SALES: sales, increase, sale, increased, reven...
# 131  SALES: revenues, revenue, million quarter, qua...
# 78   GROWTH: acquisition, acquisitions, acquired, s...
#
#                                         Representation  Representative_Docs
# 0    [growth, marketing, revenues, customers, incre...                  NaN
# 70   [medical, marketing, markets, customers, busin...                  NaN
# 26   [margin, margins, revenues, revenue, profit, p...                  NaN
# 140  [customers, marketing, customer, businesses, c...                  NaN
# 108  [decrease, revenues, decline, revenue, decreas...                  NaN
# 13   [earnings, earnings release, quarter results, ...                  NaN
# 24   [questions, open, calls, opening, closing, que...                  NaN
# 134  [products, industry, product, consumer, market...                  NaN
# 16   [margin, earnings, margins, adjusted, revenues...                  NaN
# 122  [little bit, discuss, think, details, little, ...                  NaN
# 127  [credit, portfolio, bank, prior quarter, equit...                  NaN
# 110  [say, turn, come, mike, talk, let, turning, jo...                  NaN
# 15   [morning, happy, rest, good, steve, excellent,...                  NaN
# 118  [financial results, quarter results, results q...                  NaN
# 74   [production, development, operational, infrast...                  NaN
# 63   [slide, presentation, trend, fourth, trends, f...                  NaN
# 116  [financial results, quarter results, financial...                  NaN
# 123  [sales, increase, sale, increased, revenues, g...                  NaN
# 131  [revenues, revenue, million quarter, quarter f...                  NaN
# 78   [acquisition, acquisitions, acquired, sales, i...                  NaN

# %%
topic_model.get_topic_info().head(20)
# Out:
#     Topic   Count                                               Name  \
# 0      -1  191656             -1_growth_marketing_revenues_customers
# 1       0       2                0_growth_strategic_strategy_company
# 2       1       3                      1_expenses_costs_turning_turn
# 3       2     359                                   2_morning_good__
# 4       3     263                                 3_time_currently__
# 5       4     585                      4_ahead_direct_mark_questions
# 6       5     374                                     5_ahead_hand__
# 7       6     203                 6_recorded_conference_able_limited
# 8       7     262                          7_line_lines_calls_update
# 9       8     326                      8_begin_beginning_began_ahead
# 10      9     321              9_securities_security_forward_private
# 11     10     395              10_securities_stated_discussed_future
# 12     11     356              11_conference_mike_presentation_event
# 13     12    4663  12_earnings_earnings release_quarter results_f...
# 14     13    1149                     13_morning_calls_today_pleased
# 15     14    2711                         14_morning_happy_rest_good
# 16     15    3268                15_margin_earnings_margins_adjusted
# 17     16     205                16_line_lines_presentation_recorded
# 18     17     494                 17_revenue_revenues_earnings_costs
# 19     18     346               18_earnings_accounting_gaap_expenses
#
#                                            CustomName  \
# 0                                            Outliers
# 1   GROWTH: growth, strategic, strategy, company, ...
# 2   COSTS: expenses, costs, turning, turn, , , , , ,
# 3              Topic 2: morning, good, , , , , , , ,
# 4            Topic 3: time, currently, , , , , , , ,
# 5   Topic 4: ahead, direct, mark, questions, time,...
# 6                Topic 5: ahead, hand, , , , , , , ,
# 7   Topic 6: recorded, conference, able, limited, ...
# 8   Topic 7: line, lines, calls, update, mike, jus...
# 9   Topic 8: begin, beginning, began, ahead, open,...
# 10  Topic 9: securities, security, forward, privat...
# 11  Topic 10: securities, stated, discussed, futur...
# 12  Topic 11: conference, mike, presentation, even...
# 13  EARNINGS: earnings, earnings release, quarter ...
# 14  Topic 13: morning, calls, today, pleased, happ...
# 15  Topic 14: morning, happy, rest, good, steve, e...
# 16  GROWTH: margin, earnings, margins, adjusted, r...
# 17  Topic 16: line, lines, presentation, recorded,...
# 18  SALES: revenue, revenues, earnings, costs, inc...
# 19  EARNINGS: earnings, accounting, gaap, expenses...
#
#                                        Representation  Representative_Docs
# 0   [growth, marketing, revenues, customers, incre...                  NaN
# 1   [growth, strategic, strategy, company, turning...                  NaN
# 2        [expenses, costs, turning, turn, , , , , , ]                  NaN
# 3                     [morning, good, , , , , , , , ]                  NaN
# 4                   [time, currently, , , , , , , , ]                  NaN
# 5   [ahead, direct, mark, questions, time, questio...                  NaN
# 6                       [ahead, hand, , , , , , , , ]                  NaN
# 7   [recorded, conference, able, limited, events, ...                  NaN
# 8   [line, lines, calls, update, mike, just, think...                  NaN
# 9    [begin, beginning, began, ahead, open, , , , , ]                  NaN
# 10  [securities, security, forward, private, futur...                  NaN
# 11  [securities, stated, discussed, future, remark...                  NaN
# 12  [conference, mike, presentation, event, today,...                  NaN
# 13  [earnings, earnings release, quarter results, ...                  NaN
# 14  [morning, calls, today, pleased, happy, note, ...                  NaN
# 15  [morning, happy, rest, good, steve, excellent,...                  NaN
# 16  [margin, earnings, margins, adjusted, revenues...                  NaN
# 17  [line, lines, presentation, recorded, conferen...                  NaN
# 18  [revenue, revenues, earnings, costs, income, n...                  NaN
# 19  [earnings, accounting, gaap, expenses, financi...                  NaN

# %%
topic_model.visualize_hierarchy()

# %% [markdown]
# zeroshot 2500 025

# %%
topic_model.visualize_topics()

# %%
len(topic_model.get_topic_info())
# Out:
# 77

# %%
topic_model.visualize_barchart()

# %%
topic_model.get_topic_info().sort_values(by="Count", ascending=False).head(20)
# Out:
#     Topic  Count                                               Name  \
# 0      -1  56034       -1_questions_session_conference_presentation
# 6       5  43452                       5_sales_sale_selling_revenue
# 12     11  33880                    11_growth_growing_increase_grow
# 8       7  30243  7_earnings_earnings release_financial results_...
# 7       6  21584               6_marketing_customers_market_product
# 14     13  21268                     13_costs_cost_revenue_spending
# 10      9  20574           9_cash flow_cash_balance sheet_financial
# 9       8  15417            8_operate_employees_operation_operating
# 2       1  11074            1_risk_prospects_forward looking_future
# 4       3  10970                 3_demand_decline_markets_customers
# 39     38  10592                   38_phase_research_second_results
# 1       0   7047   0_regulatory_approval_commission_forward looking
# 5       4   6888                4_markets_economic_market_financial
# 3       2   5433               2_markets_market_marketing_strategic
# 13     12   5036                12_rates_percent_fiscal year_fiscal
# 37     36   4161             36_debt_financing_balance sheet_credit
# 59     58   3726         58_technologies_mobile_platform_technology
# 68     67   3254  67_press release_quarter results_financial res...
# 69     68   3187                      68_little bit_okay_little_bit
# 73     72   3113                         72_chris_ll turn_tim_scott
#
#                                            CustomName  \
# 0                                            Outliers
# 6   SALES: sales, sale, selling, revenue, decrease...
# 12  GROWTH: growth, growing, increase, grow, busin...
# 8   EARNINGS: earnings, earnings release, financia...
# 7   MARKETING: marketing, customers, market, produ...
# 14  COSTS: costs, cost, revenue, spending, price, ...
# 10  INVESTMENTS: cash flow, cash, balance sheet, f...
# 9   OPERATIONS: operate, employees, operation, ope...
# 2   RISK: risk, prospects, forward looking, future...
# 4   GEOGRAPHY: demand, decline, markets, customers...
# 39  Topic 38: phase, research, second, results, st...
# 1   REGULATION: regulatory, approval, commission, ...
# 5   GEOGRAPHY: markets, economic, market, financia...
# 3   GEOGRAPHY: markets, market, marketing, strateg...
# 13  SALES: rates, percent, fiscal year, fiscal, ra...
# 37  Topic 36: debt, financing, balance sheet, cred...
# 59  Topic 58: technologies, mobile, platform, tech...
# 68  Topic 67: press release, quarter results, fina...
# 69  Topic 68: little bit, okay, little, bit, tell,...
# 73  Topic 72: chris, ll turn, tim, scott, let turn...
#
#                                        Representation  Representative_Docs
# 0   [questions, session, conference, presentation,...                  NaN
# 6   [sales, sale, selling, revenue, decrease, mark...                  NaN
# 12  [growth, growing, increase, grow, business, de...                  NaN
# 8   [earnings, earnings release, financial results...                  NaN
# 7   [marketing, customers, market, product, busine...                  NaN
# 14  [costs, cost, revenue, spending, price, financ...                  NaN
# 10  [cash flow, cash, balance sheet, financial, fi...                  NaN
# 9   [operate, employees, operation, operating, man...                  NaN
# 2   [risk, prospects, forward looking, future, sta...                  NaN
# 4   [demand, decline, markets, customers, market, ...                  NaN
# 39  [phase, research, second, results, stage, medi...                  NaN
# 1   [regulatory, approval, commission, forward loo...                  NaN
# 5   [markets, economic, market, financial, busines...                  NaN
# 3   [markets, market, marketing, strategic, acquis...                  NaN
# 13  [rates, percent, fiscal year, fiscal, rate, re...                  NaN
# 37  [debt, financing, balance sheet, credit, lever...                  NaN
# 59  [technologies, mobile, platform, technology, c...                  NaN
# 68  [press release, quarter results, financial res...                  NaN
# 69  [little bit, okay, little, bit, tell, point, i...                  NaN
# 73  [chris, ll turn, tim, scott, let turn, say, br...                  NaN

# %%
topic_model.visualize_hierarchy()
